# %%
import polars as pl

df = pl.read_parquet("global_filing_data.parquet")
print(df)
print(df['ticker'].unique())
# Out:
# shape: (123, 4)
# ┌────────┬──────┬────────────┬─────────────────────────────────┐
# │ ticker ┆ form ┆ date       ┆ content                         │
# │ ---    ┆ ---  ┆ ---        ┆ ---                             │
# │ str    ┆ str  ┆ date       ┆ str                             │
# ╞════════╪══════╪════════════╪═════════════════════════════════╡
# │ NVDA   ┆ 10-K ┆ 2025-02-26 ┆ Table of Contents               │
# │        ┆      ┆            ┆                                 │
# │        ┆      ┆            ┆ Item 7. Man…                    │
# │ NVDA   ┆ 10-K ┆ 2024-02-21 ┆ Table of Contents               │
# │        ┆      ┆            ┆                                 │
# │        ┆      ┆            ┆ Item 7. Man…                    │
# │ NVDA   ┆ 10-K ┆ 2023-02-24 ┆ Table of Contents               │
# │        ┆      ┆            ┆                                 │
# │        ┆      ┆            ┆ ITEM 7. MAN…                    │
# ...

# %%
df.describe()
# Out:
# shape: (9, 8)
# ┌────────────┬──────────────┬──────────────┬────────┬─────────┬──────────────┬──────────────┬──────┐
# │ statistic  ┆ document_url ┆ content      ┆ ticker ┆ cik     ┆ utc_timestam ┆ est_timestam ┆ type │
# │ ---        ┆ ---          ┆ ---          ┆ ---    ┆ ---     ┆ p            ┆ p            ┆ ---  │
# │ str        ┆ str          ┆ str          ┆ str    ┆ str     ┆ ---          ┆ ---          ┆ str  │
# │            ┆              ┆              ┆        ┆         ┆ str          ┆ str          ┆      │
# ╞════════════╪══════════════╪══════════════╪════════╪═════════╪══════════════╪══════════════╪══════╡
# │ count      ┆ 60           ┆ 60           ┆ 60     ┆ 60      ┆ 60           ┆ 60           ┆ 60   │
# │ null_count ┆ 0            ┆ 0            ┆ 0      ┆ 0       ┆ 0            ┆ 0            ┆ 0    │
# │ mean       ┆ null         ┆ null         ┆ null   ┆ null    ┆ 2013-09-18   ┆ 2013-09-18   ┆ null │
# ...

# %%
df.unique("ticker")
# Out:
# shape: (4, 7)
# ┌─────────────────────────┬──────────────┬────────┬─────────┬───────────────┬───────────────┬──────┐
# │ document_url            ┆ content      ┆ ticker ┆ cik     ┆ utc_timestamp ┆ est_timestamp ┆ type │
# │ ---                     ┆ ---          ┆ ---    ┆ ---     ┆ ---           ┆ ---           ┆ ---  │
# │ str                     ┆ str          ┆ str    ┆ str     ┆ datetime[μs]  ┆ datetime[μs]  ┆ str  │
# ╞═════════════════════════╪══════════════╪════════╪═════════╪═══════════════╪═══════════════╪══════╡
# │ https://www.sec.gov/Arc ┆ item 7.      ┆        ┆ 68589   ┆ 2013-02-21    ┆ 2013-02-21    ┆ 10-K │
# │ hives/e…                ┆ management's ┆        ┆         ┆ 21:03:45      ┆ 16:03:45      ┆      │
# │                         ┆ discussio…   ┆        ┆         ┆               ┆               ┆      │
# │ https://www.sec.gov/Arc ┆ item 7.      ┆ STRI   ┆ 1473597 ┆ 2012-03-14    ┆ 2012-03-14    ┆ 10-K │
# ...
